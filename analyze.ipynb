# %%
import pandas as pd

# %%
df = pd.read_json('data/tutors.jsonl', lines=True)
df['subjects'] = df['subjects'].apply(lambda v: ', '.join(v) if isinstance(v, list) else v)
df.to_csv('data/tutors.csv', index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv('data/tutors.csv', encoding='utf-8-sig')

# %%
men_only = df[(df['gender'] == 'Man')]

men_only.to_csv('data/men_only.csv', index=False, encoding='utf-8-sig')
